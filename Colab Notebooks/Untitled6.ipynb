# %%
import pandas as pd

# ১০০টি বাছাইকৃত ইডিওম ও ফ্রেজের সম্পূর্ণ লিস্ট
data = [
    ["In full swing", "পুরোদমে", "The preparation for the upcoming recruitment test is in full swing."],
    ["Irony of fate", "ভাগ্যের পরিহাস", "By the irony of fate, the brilliant student failed the initial screening."],
    ["Kith and kin", "আত্মীয়স্বজন", "He invited all his kith and kin to his graduation party."],
    ["Lame excuse", "বাজে ওজর", "The manager didn't accept his lame excuse for being late."],
    ["Leave no stone unturned", "চেষ্টার ত্রুটি না করা", "I will leave no stone unturned to secure a position in the central bank."],
    ["Lion's share", "সিংহভাগ", "The informal sector provides the lion's share of employment in rural areas."],
    ["Loaves and fishes", "ব্যক্তিগত স্বার্থ", "Many politicians are only after the loaves and fishes of office."],
    ["Look down upon", "ঘৃণা করা বা নিচু চোখে দেখা", "We should not look down upon the poor."],
    ["Maiden speech", "প্রথম বক্তৃতা", "His maiden speech in the debate club was highly praised."],
    ["Make both ends meet", "আয়-ব্যয়ের ভারসাম্য রাখা", "With inflation rising, it's hard for low-income families to make both ends meet."],
    ["Man of straw", "অপদার্থ লোক", "A man of straw cannot command respect in the corporate world."],
    ["Move heaven and earth", "যথাসাধ্য চেষ্টা করা", "He is moving heaven and earth to finish his master's thesis on time."],
    ["Narrow escape", "অল্পের জন্য রক্ষা", "The passengers had a narrow escape from the terrible accident."],
    ["Now and then", "মাঝে মাঝে", "I visit my hometown now and then to meet my old friends."],
    ["On the spur of the moment", "মুহূর্তের উত্তেজনায়", "He bought the expensive laptop on the spur of the moment."],
    ["Open secret", "যে গোপন কথা সবাই জানে", "It is an open secret that the company is facing a financial crisis."],
    ["Out of order", "বিকল বা নষ্ট", "The elevator in the academic building is out of order."],
    ["Out of sorts", "অসুস্থ বা মন খারাপ", "He has been feeling a bit out of sorts since yesterday morning."],
    ["Out of the question", "অসম্ভব", "Quitting the preparation right now is out of the question."],
    ["Part and parcel", "অবিচ্ছেদ্য অংশ", "Data analysis has become a part and parcel of modern academic research."],
    ["Point blank", "সরাসরি", "He refused the lucrative offer point blank."],
    ["Pros and cons", "সুবিধা-অসুবিধা বা খুঁটিনাটি", "You must weigh the pros and cons before making a career switch."],
    ["Put up with", "সহ্য করা", "It is difficult to put up with such unprofessional behavior at work."],
    ["Rank and file", "সাধারণ কর্মী", "The rank and file of the organization demanded better working conditions."],
    ["Red tape", "আমলাতান্ত্রিক জটিলতা", "Foreign investors often complain about red tape in economic zones."],
    ["Right hand man", "প্রধান বা বিশ্বস্ত সহকারী", "He is the right hand man of the managing director."],
    ["Root and branch", "সম্পূর্ণভাবে", "Corruption must be eliminated root and branch from society."],
    ["Round the clock", "দিনরাত ২৪ ঘণ্টা", "The resident students in the hall study round the clock before finals."],
    ["Safe and sound", "নিরাপদে", "They reached the campus safe and sound after the long bus journey."],
    ["Salt of the earth", "শ্রেষ্ঠ বা সবচেয়ে সৎ ব্যক্তি", "Volunteers who work selflessly are the salt of the earth."],
    ["Scapegoat", "বলির পাঁঠা", "He was made a scapegoat for the management's failure."],
    ["Show white feather", "কাপুরুষতা দেখানো", "A true leader never shows white feather in times of severe crisis."],
    ["Sine die", "অনির্দিষ্টকালের জন্য", "The official meeting was postponed sine die due to unavoidable reasons."],
    ["Slow coach", "অলস প্রকৃতির লোক", "We cannot finish this group project on time with a slow coach in our team."],
    ["Smell a rat", "সন্দেহ করা", "Seeing the financial documents tampered with, the auditor smelled a rat."],
    ["Snake in the grass", "গুপ্ত শত্রু", "Beware of him; he pretends to be a friend but is actually a snake in the grass."],
    ["Soft soap", "তোষামোদ", "Using soft soap will not help you pass the tough viva board."],
    ["Spare no pains", "চেষ্টার কসুর না করা", "The researchers spared no pains to develop the accurate mathematical model."],
    ["Stand in good stead", "উপকারে আসা", "Your vast knowledge of mathematics will stand you in good stead in the analytical section."],
    ["Steer clear of", "এড়িয়ে চলা", "Always try to steer clear of negative people during your exam prep."],
    ["Stone's throw", "খুব কাছে", "The central library is just a stone's throw from his residential hall."],
    ["Storm in a teacup", "তুচ্ছ বিষয়ে প্রবল উত্তেজনা", "Their fierce argument over the seating arrangement was just a storm in a teacup."],
    ["Swan song", "শেষ কীর্তি", "The brilliant research paper published last month was the professor's swan song."],
    ["Take to task", "তিরস্কার করা", "The intern was taken to task by the HR department for his careless mistakes."],
    ["Tall talk", "বড় বড় কথা", "Nobody believes him because he is always full of tall talk."],
    ["Three score", "ষাট (৬০)", "The wise man lived for three score and ten years."],
    ["Time and again", "বারবার", "He has been warned time and again about his poor time management."],
    ["Tit for tat", "যেমন কুকুর তেমন মুগুর", "He broke my pen, so I hid his notebook; it was simply tit for tat."],
    ["To and fro", "এদিক-ওদিক", "The worried candidate was walking to and fro in the corridor before the interview."],
    ["Tooth and nail", "প্রাণপণে", "We fought tooth and nail to solve the complex dynamic equations."],
    ["Turn a deaf ear", "কান না দেওয়া", "The stubborn child turned a deaf ear to his mother's advice."],
    ["Under a cloud", "সন্দেহের পাত্র", "After the recent scam, the branch manager has been under a cloud."],
    ["Up to the mark", "মানসম্মত", "His performance in the final assessment was not quite up to the mark."],
    ["Ups and downs", "উত্থান-পতন", "Every successful entrepreneur has seen many ups and downs in life."],
    ["Wear and tear", "ব্যবহারজনিত ক্ষয়", "The machinery suffered heavy wear and tear over the years."],
    ["Well-to-do", "সচ্ছল", "He comes from a well-to-do family in the district."],
    ["White collar", "ভদ্রস্থ বা অফিশিয়াল কাজ", "Many graduates dream of white collar jobs in commercial banks."],
    ["Wild goose chase", "পণ্ডশ্রম", "Trying to find the lost file in that huge archive is a wild goose chase."],
    ["With flying colours", "বিপুল সাফল্যে", "He passed his rigorous Master's defense with flying colours."],
    ["With one voice", "একবাক্যে", "The committee rejected the absurd proposal with one voice."],
    ["Word for word", "হুবহু", "Try to memorize the exact definition word for word."],
    ["Worth one's while", "লাভজনক বা সময় দেওয়ার মতো", "Reading this dense economic report is really worth your while."],
    ["Yellow journalism", "ভিত্তিহীন বা চাঞ্চল্যকর সাংবাদিকতা", "We should not blindly trust portals that practice yellow journalism."],
    ["Yeoman's service", "নিঃস্বার্থ বা বিপুল সাহায্য", "The local student association did yeoman's service during the winter crisis."],
    ["Achilles' heel", "দুর্বলতম জায়গা", "Quantitative math is easy for him, but English grammar is his Achilles' heel."],
    ["Add insult to injury", "কাটা ঘায়ে নুনের ছিটা", "First I lost my notes, and then my laptop crashed—it just added insult to injury."],
    ["At random", "উদ্দেশ্যহীনভাবে", "The teacher picked exam topics at random."],
    ["Bad debt", "কুঋণ বা অনাদায়ী ঋণ", "The bank is struggling to recover millions of takas in bad debt."],
    ["Bear in mind", "মনে রাখা", "Bear in mind that consistency is the key to cracking administrative exams."],
    ["Behind closed doors", "গোপনে", "The crucial financial decisions were taken behind closed doors."],
    ["Bell the cat", "বিপদের ঝুঁকি নেওয়া", "Everyone wants to complain about the boss, but who will bell the cat?"],
    ["Blow one's own trumpet", "নিজের ঢোল নিজে পেটানো", "He is always blowing his own trumpet about his academic records."],
    ["Blue ribbon", "সর্বোচ্চ সম্মান", "The software company won the blue ribbon for its innovative UI design."],
    ["Break the ice", "নীরবতা ভাঙা", "He started with a light joke to break the ice at the tense board meeting."],
    ["Breathe one's last", "শেষ নিশ্বাস ত্যাগ করা", "The eminent scientist breathed his last in a city hospital yesterday."],
    ["Broad daylight", "দিনের আলোতে", "The audacious robbery took place in broad daylight right in front of the bank."],
    ["Brown study", "দিবা স্বপ্ন বা গভীর চিন্তা", "He was in a brown study and didn't hear his friend calling his name."],
    ["Bull market", "চাঙ্গা বাজার (শেয়ার বাজার)", "Investors make a lot of profit during a long bull market."],
    ["Burn the midnight oil", "গভীর রাত পর্যন্ত পড়াশোনা করা", "Securing a top AD position requires burning the midnight oil for months."],
    ["By and by", "শীঘ্র", "Don't worry, the economic situation will stabilize by and by."],
    ["By and large", "মোটের উপর", "By and large, the seminar on social entrepreneurship was a huge success."],
    ["Call in question", "সন্দেহ করা", "You cannot call his dedication in question."],
    ["Cast aside", "বাতিল করা", "You should cast aside your self-doubt and focus on the syllabus."],
    ["Catch red-handed", "হাতেনাতে ধরা", "The corrupt official was caught red-handed while taking the bribe."],
    ["Close shave", "অল্পের জন্য রক্ষা", "I had a close shave when the speeding truck drove past my motorcycle."],
    ["Cold war", "স্নায়ুযুদ্ধ", "There is a cold war going on between the two rival departments."],
    ["Come to light", "প্রকাশিত হওয়া", "The hidden facts about the informal sector eventually came to light during the survey."],
    ["Cut a sorry figure", "খারাপ ফল করা", "Due to lack of revision, he cut a sorry figure in the preliminary exam."],
    ["Cut to the quick", "মর্মান্তিক আঘাত দেওয়া", "His unfair criticism cut me to the quick."],
    ["Day in and day out", "দিনের পর দিন", "He has been practicing model tests day in and day out."],
    ["Dead language", "যে ভাষা এখন আর ব্যবহৃত হয় না", "Latin is now considered a dead language."],
    ["Dog in the manger", "যে নিজে ভোগ করে না, অন্যকেও দেয় না", "Stop being a dog in the manger and let others read the reference book if you are not using it."],
    ["Double dealing", "কপটতা", "Honest professionals always hate double dealing in corporate environments."],
    ["Draw the line", "সীমারেখা টানা", "You must draw the line between your study time and social media usage."],
    ["Ever and anon", "মাঝে মাঝে", "The poet used to visit the quiet countryside ever and anon to find peace."],
    ["Every inch", "পুরোপুরি", "Dressed in his formal suit, he looked every inch a professional banker."],
    ["Eye-wash", "ধোঁকা", "The sudden policy change is nothing but an eye-wash to pacify the general public."],
    ["Face the music", "কৃতকর্মের ফল ভোগ করা", "If you neglect your studies now, you will have to face the music in the exam hall."],
    ["Fall short of", "ঘাটতি হওয়া", "The data collection fell short of our initial target for the thesis."],
    ["Make up one's mind", "মনস্থির করা", "You need to make up your mind and strictly follow a study routine."]
]

# ১. এক্সেলে সেভ করার কমান্ড
df = pd.DataFrame(data, columns=["Idiom / Phrase", "Meaning (Bengali)", "Example Sentence"])
excel_filename = "100_Important_Idioms.xlsx"
df.to_excel(excel_filename, index=False)
print(f"✅ Excel sheet successfully created: {excel_filename}")

# ২. HTML ও PDF এর জন্য ডিজাইন
html_content = f"""
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>Top 100 Idioms & Phrases</title>
    <style>
        @page {{ size: A4; margin: 20mm; }}
        body {{
            font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
            color: #2c3e50;
            background-color: #fff;
        }}
        .header {{ text-align: center; margin-bottom: 25px; }}
        h2 {{
            color: #004080;
            border-bottom: 3px solid #004080;
            display: inline-block;
            padding-bottom: 5px;
            margin-bottom: 5px;
        }}
        .subtitle {{ font-style: italic; color: #555; font-size: 14px; }}
        table {{ width: 100%; border-collapse: collapse; margin-top: 15px; font-size: 13px; }}
        th {{
            background-color: #004080;
            color: #ffffff;
            padding: 12px;
            text-align: left;
            border: 1px solid #bdc3c7;
        }}
        td {{ padding: 10px; border: 1px solid #bdc3c7; vertical-align: top; }}
        tr {{ page-break-inside: avoid; }} /* এক লাইনের ডেটা যেন ভেঙে পরের পৃষ্ঠায় না যায় */
        tr:nth-child(even) {{ background-color: #f8f9fa; }}
        .idiom {{ font-weight: bold; color: #d35400; }}
        .number {{ font-weight: bold; color: #004080; width: 5%; text-align: center; }}
    </style>
</head>
<body>
    <div class="header">
        <h2>Top 100 Idioms & Phrases Tracker</h2>
        <div class="subtitle">Comprehensive Preparation Guide for Competitive Exams</div>
    </div>
    <table>
        <thead>
            <tr>
                <th class="number">#</th>
                <th style="width: 25%;">Idiom / Phrase</th>
                <th style="width: 30%;">Meaning (Bengali)</th>
                <th style="width: 40%;">Example Sentence</th>
            </tr>
        </thead>
        <tbody>
"""

# ডেটা টেবিলে ইনপুট দেওয়া
for idx, row in enumerate(data, start=1):
    html_content += f"""
            <tr>
                <td class="number">{idx}</td>
                <td class="idiom">{row[0]}</td>
                <td>{row[1]}</td>
                <td>{row[2]}</td>
            </tr>
    """

html_content += """
        </tbody>
    </table>
</body>
</html>
"""

html_filename = "100_Important_Idioms_A4.html"
with open(html_filename, "w", encoding="utf-8") as file:
    file.write(html_content)

print(f"✅ Printable A4 format generated: {html_filename}")
print("💡 Tip: Open the HTML file in your browser and press Ctrl + P to save it as a PDF!")
# Out:
# ✅ Excel sheet successfully created: 100_Important_Idioms.xlsx
# ✅ Printable A4 format generated: 100_Important_Idioms_A4.html
# 💡 Tip: Open the HTML file in your browser and press Ctrl + P to save it as a PDF!
